# %%
from pathlib import Path
print(Path.cwd())
# Out:
# d:\repo\src

# %%
import pandas as pd
from pathlib import Path

RAW_DIR = Path.cwd().parent / "data" / "raw"
PROCESSED_DIR = Path.cwd().parent / "data" / "processed"
PROCESSED_DIR.mkdir(parents=True, exist_ok=True)

# %%
print(RAW_DIR)
print(RAW_DIR.exists())
# Out:
# d:\repo\data\raw
# True

# %%
routes = pd.read_csv(RAW_DIR/"routes.txt")
routes
# Out:
#      route_id agency_id  route_short_name  \
# 0           6     PMPML               100
# 1           7     PMPML               100
# 2          10     PMPML               103
# 3          13     PMPML               103
# 4          14     PMPML               104
# ..        ...       ...               ...
# 489      1045     PMPML                99
# 490      1048     PMPML               AP2
# 491      1049     PMPML               AP2
# 492      1108     PMPML  METRO SHUTTLE 20
# 493      1109     PMPML  METRO SHUTTLE 20
#
#                                        route_long_name  route_type
# 0    Hinjawadi Maan Phase 3 to Ma Na Pa Dengle Pul ...           3
# 1    Ma Na Pa Dengle Pul Nadikhathi to Hinjawadi Ma...           3
# 2                         Kothrud Depot to Katraj (UP)           3
# 3                       Katraj to Kothrud Depot (DOWN)           3
# 4                     Dsk Vishwa to Shivaji Nagar (UP)           3
# ..                                                 ...         ...
# 489                  Kothrud Depot to Kekan Gas (DOWN)           3
# 490            Upper Depot to Katraj Kondhwa Road (UP)           3
# 491          Katraj Kondhwa Road to Upper Depot (DOWN)           3
# 492  PANCHSHIL TOWERS E VON GATE NO. 2 Kharadi to R...           3
# 493  Ramwadi Metro Station to PANCHSHIL TOWERS E VO...           3
#
# [494 rows x 5 columns]

# %%
routes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 494 entries, 0 to 493
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   route_id          494 non-null    int64
#  1   agency_id         494 non-null    object
#  2   route_short_name  494 non-null    object
#  3   route_long_name   494 non-null    object
#  4   route_type        494 non-null    int64
# dtypes: int64(2), object(3)
# memory usage: 19.4+ KB
